# %%
tsla <- 'tsla.csv'
nio <- 'nio.csv'
li <- 'li.csv'
xpev <- 'xpev.csv'
chpt <- 'chpt.csv'
ptra <- 'ptra.csv'
rivn <- 'rivn.csv'
lcid <- 'lcid.csv'
wbx <- 'wbx.csv'
blnk <- 'blnk.csv'

# %%
tsla <- read.csv(tsla)
nio <- read.csv(nio)
li <- read.csv(li)
xpev <- read.csv(xpev)
chpt <- read.csv(chpt)
ptra <- read.csv(ptra)
rivn <- read.csv(rivn)
lcid <- read.csv(lcid)
wbx <- read.csv(wbx)
blnk <- read.csv(blnk)

# %%
tsla
# Out:
#     Date       Open   High   Low    Close. Adj.Close.. Volume
# 1   2022-11-23 173.57 183.62 172.50 183.20 183.20      109191900
# 2   2022-11-22 168.63 170.92 166.19 169.91 169.91       78452300
# 3   2022-11-21 175.85 176.77 167.54 167.87 167.87       92882700
# 4   2022-11-18 185.05 185.19 176.55 180.19 180.19       75904900
# 5   2022-11-17 183.96 186.16 180.90 183.17 183.17       64336000
# 6   2022-11-16 191.51 192.57 185.66 186.92 186.92       66567600
# 7   2022-11-15 195.88 200.82 192.06 194.42 194.42       91293800
# 8   2022-11-14 192.77 195.73 186.34 190.95 190.95       92226600
# 9   2022-11-11 186.00 196.52 182.59 195.97 195.97      114229200
# 10  2022-11-10 189.90 191.00 180.03 190.72 190.72      132703000
# 11  2022-11-09 190.78 195.89 177.12 177.59 177.59      127062700
# 12  2022-11-08 194.02 195.20 186.75 191.30 191.30      128803400
# 13  2022-11-07 208.65 208.90 196.66 197.08 197.08       93916500
# ...
